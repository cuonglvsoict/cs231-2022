# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive')

# TODO: Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment1/'
FOLDERNAME = 'cs231n/assignments/assignment1/'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# This downloads the CIFAR-10 dataset to your Drive
# if it doesn't already exist.
# %cd /content/drive/My\ Drive/$FOLDERNAME/cs231n/datasets/
# !bash get_datasets.sh
# %cd /content/drive/My\ Drive/$FOLDERNAME
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/cs231n/assignments/assignment1/cs231n/datasets
# /content/drive/My Drive/cs231n/assignments/assignment1

# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    
    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside `cs231n/classifiers/softmax.py`.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.350085
# sanity check: 2.302585

# %% [markdown]
# **Inline Question 1**
#
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# $\color{blue}{\textit Your Answer:}$ *Fill this in*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: -0.133026 analytic: -0.133026, relative error: 2.934481e-07
# numerical: -2.118884 analytic: -2.118884, relative error: 6.156888e-09
# numerical: -2.598719 analytic: -2.598719, relative error: 1.804581e-08
# numerical: -0.274471 analytic: -0.274471, relative error: 1.568394e-08
# numerical: -3.032595 analytic: -3.032595, relative error: 2.405418e-08
# numerical: -2.696177 analytic: -2.696177, relative error: 1.428615e-08
# numerical: 2.835199 analytic: 2.835199, relative error: 2.076213e-08
# numerical: -1.765877 analytic: -1.765878, relative error: 1.266639e-08
# numerical: -1.615020 analytic: -1.615020, relative error: 6.564029e-09
# numerical: 1.726587 analytic: 1.726586, relative error: 2.605682e-08
# numerical: -0.473672 analytic: -0.473672, relative error: 3.250953e-08
# numerical: -0.789837 analytic: -0.789837, relative error: 4.349507e-09
# numerical: -2.175959 analytic: -2.175959, relative error: 1.459609e-08
# numerical: 0.673149 analytic: 0.673149, relative error: 2.338961e-08
# numerical: -0.752839 analytic: -0.752839, relative error: 6.446051e-09
# numerical: -1.563961 analytic: -1.563961, relative error: 3.835720e-08
# numerical: 0.809902 analytic: 0.809901, relative error: 4.651587e-08
# numerical: 1.965244 analytic: 1.965244, relative error: 2.840303e-08
# numerical: 1.961046 analytic: 1.961046, relative error: 4.637387e-09
# numerical: -1.993969 analytic: -1.993969, relative error: 2.210418e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.350085e+00 computed in 0.124093s
# vectorized loss: 2.350085e+00 computed in 0.013203s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
from cs231n.classifiers import Softmax
softmax = Softmax()
loss_hist = softmax.train(X_train, y_train, learning_rate=1e-7, reg=1e4, num_iters=1000, verbose=True)

y_train_pred = softmax.predict(X_train)
y_test_pred = softmax.predict(X_test)

train_acc = np.sum(y_train_pred == y_train) / y_train.shape[0]
test_acc = np.sum(y_test_pred == y_test) / y_test.shape[0]
print(f"Accuracy on training set: {train_acc * 100}%")
print(f"Accuracy on test set: {test_acc * 100}%")

plt.plot(loss_hist)
plt.show()
# Out:
# iteration 0 / 1000: loss 313.864533
# iteration 100 / 1000: loss 210.213294
# iteration 200 / 1000: loss 140.624471
# iteration 300 / 1000: loss 94.722316
# iteration 400 / 1000: loss 63.898201
# iteration 500 / 1000: loss 43.325127
# iteration 600 / 1000: loss 29.733970
# iteration 700 / 1000: loss 20.428072
# iteration 800 / 1000: loss 14.419978
# iteration 900 / 1000: loss 10.245316
# Accuracy on training set: 32.68571428571428%
# Accuracy on test set: 34.0%

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.

results = {}
best_val = -1
best_softmax = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################

# Provided as a reference. You may or may not want to change these hyperparameters
learning_rates = [1e-6, 5e-6, 1e-7, 5e-7]
regularization_strengths = [1e4, 2e4, 3e4, 4e4, 5e4]

# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

for lr in learning_rates:
  for rs in regularization_strengths:
    print(f"Training with learning rate = {lr} and reg = {rs}:")
    softmax = Softmax()
    loss_hist = softmax.train(X_train, y_train, learning_rate=lr, reg=rs, num_iters=1500, verbose=True)

    y_train_pred = softmax.predict(X_train)
    y_val_pred = softmax.predict(X_val)

    train_acc = np.sum(y_train_pred == y_train) / y_train.shape[0]
    val_acc = np.sum(y_val_pred == y_val) / y_val.shape[0]

    results[(lr, rs)] = (train_acc, val_acc)
    if best_val < val_acc:
      best_val = val_acc
      best_softmax = softmax

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# Training with learning rate = 1e-06 and reg = 10000.0:
# iteration 0 / 1500: loss 313.383230
# iteration 100 / 1500: loss 7.338352
# iteration 200 / 1500: loss 2.137632
# iteration 300 / 1500: loss 1.945036
# iteration 400 / 1500: loss 1.996049
# iteration 500 / 1500: loss 2.025579
# iteration 600 / 1500: loss 2.004758
# iteration 700 / 1500: loss 2.017190
# iteration 800 / 1500: loss 1.979115
# iteration 900 / 1500: loss 2.109242
# iteration 1000 / 1500: loss 2.017890
# iteration 1100 / 1500: loss 2.060767
# iteration 1200 / 1500: loss 2.012429
# iteration 1300 / 1500: loss 1.982737
# iteration 1400 / 1500: loss 1.910063
# Training with learning rate = 1e-06 and reg = 20000.0:
# iteration 0 / 1500: loss 625.123783
# iteration 100 / 1500: loss 2.299670
# iteration 200 / 1500: loss 2.083195
# iteration 300 / 1500: loss 2.062001
# iteration 400 / 1500: loss 2.087661
# iteration 500 / 1500: loss 2.091852
# iteration 600 / 1500: loss 2.064004
# iteration 700 / 1500: loss 2.067425
# iteration 800 / 1500: loss 2.053776
# iteration 900 / 1500: loss 2.086260
# iteration 1000 / 1500: loss 2.086643
# iteration 1100 / 1500: loss 2.128226
# iteration 1200 / 1500: loss 2.101799
# iteration 1300 / 1500: loss 2.142164
# iteration 1400 / 1500: loss 2.074369
# Training with learning rate = 1e-06 and reg = 30000.0:
# iteration 0 / 1500: loss 922.525723
# iteration 100 / 1500: loss 2.101390
# iteration 200 / 1500: loss 2.121870
# iteration 300 / 1500: loss 2.149254
# iteration 400 / 1500: loss 2.174833
# iteration 500 / 1500: loss 2.081671
# iteration 600 / 1500: loss 2.180265
# iteration 700 / 1500: loss 2.101108
# iteration 800 / 1500: loss 2.100784
# iteration 900 / 1500: loss 2.174808
# iteration 1000 / 1500: loss 2.115316
# iteration 1100 / 1500: loss 2.134706
# iteration 1200 / 1500: loss 2.067222
# iteration 1300 / 1500: loss 2.095469
# iteration 1400 / 1500: loss 2.092470
# Training with learning rate = 1e-06 and reg = 40000.0:
# iteration 0 / 1500: loss 1224.994266
# iteration 100 / 1500: loss 2.128890
# iteration 200 / 1500: loss 2.138617
# iteration 300 / 1500: loss 2.180303
# iteration 400 / 1500: loss 2.158770
# iteration 500 / 1500: loss 2.154273
# iteration 600 / 1500: loss 2.150190
# iteration 700 / 1500: loss 2.142967
# iteration 800 / 1500: loss 2.174766
# iteration 900 / 1500: loss 2.159476
# iteration 1000 / 1500: loss 2.090828
# iteration 1100 / 1500: loss 2.098995
# iteration 1200 / 1500: loss 2.125711
# iteration 1300 / 1500: loss 2.070126
# iteration 1400 / 1500: loss 2.104510
# Training with learning rate = 1e-06 and reg = 50000.0:
# iteration 0 / 1500: loss 1555.454455
# iteration 100 / 1500: loss 2.147455
# iteration 200 / 1500: loss 2.155942
# iteration 300 / 1500: loss 2.204400
# iteration 400 / 1500: loss 2.158886
# iteration 500 / 1500: loss 2.141221
# iteration 600 / 1500: loss 2.120364
# iteration 700 / 1500: loss 2.171627
# iteration 800 / 1500: loss 2.134486
# iteration 900 / 1500: loss 2.151151
# iteration 1000 / 1500: loss 2.179251
# iteration 1100 / 1500: loss 2.165136
# iteration 1200 / 1500: loss 2.176880
# iteration 1300 / 1500: loss 2.200984
# iteration 1400 / 1500: loss 2.200189
# Training with learning rate = 5e-06 and reg = 10000.0:
# iteration 0 / 1500: loss 309.119278
# iteration 100 / 1500: loss 2.168175
# iteration 200 / 1500: loss 2.511927
# iteration 300 / 1500: loss 2.143205
# iteration 400 / 1500: loss 2.138042
# iteration 500 / 1500: loss 2.329544
# iteration 600 / 1500: loss 2.093134
# iteration 700 / 1500: loss 2.056389
# iteration 800 / 1500: loss 2.135169
# iteration 900 / 1500: loss 2.269888
# iteration 1000 / 1500: loss 2.123205
# iteration 1100 / 1500: loss 2.215675
# iteration 1200 / 1500: loss 2.150471
# iteration 1300 / 1500: loss 2.443431
# iteration 1400 / 1500: loss 2.183702
# Training with learning rate = 5e-06 and reg = 20000.0:
# iteration 0 / 1500: loss 622.574437
# iteration 100 / 1500: loss 2.266495
# iteration 200 / 1500: loss 2.186894
# iteration 300 / 1500: loss 2.433373
# iteration 400 / 1500: loss 2.767977
# iteration 500 / 1500: loss 2.587843
# iteration 600 / 1500: loss 2.662393
# iteration 700 / 1500: loss 2.290916
# iteration 800 / 1500: loss 2.472239
# iteration 900 / 1500: loss 2.317427
# iteration 1000 / 1500: loss 2.444550
# iteration 1100 / 1500: loss 2.226854
# iteration 1200 / 1500: loss 2.212637
# iteration 1300 / 1500: loss 2.159579
# iteration 1400 / 1500: loss 2.352848
# Training with learning rate = 5e-06 and reg = 30000.0:
# iteration 0 / 1500: loss 926.157306
# iteration 100 / 1500: loss 2.431482
# iteration 200 / 1500: loss 2.407450
# iteration 300 / 1500: loss 2.690450
# iteration 400 / 1500: loss 3.032603
# iteration 500 / 1500: loss 2.312195
# iteration 600 / 1500: loss 2.795172
# iteration 700 / 1500: loss 2.973223
# iteration 800 / 1500: loss 2.910284
# iteration 900 / 1500: loss 3.133101
# iteration 1000 / 1500: loss 2.572579
# iteration 1100 / 1500: loss 2.671011
# iteration 1200 / 1500: loss 2.309091
# iteration 1300 / 1500: loss 3.295332
# iteration 1400 / 1500: loss 2.752538
# Training with learning rate = 5e-06 and reg = 40000.0:
# iteration 0 / 1500: loss 1244.498424
# iteration 100 / 1500: loss 2.466515
# iteration 200 / 1500: loss 3.584386
# iteration 300 / 1500: loss 3.200892
# iteration 400 / 1500: loss 3.110233
# iteration 500 / 1500: loss 2.445483
# iteration 600 / 1500: loss 3.288872
# iteration 700 / 1500: loss 3.214926
# iteration 800 / 1500: loss 2.743595
# iteration 900 / 1500: loss 3.161933
# iteration 1000 / 1500: loss 3.118986
# iteration 1100 / 1500: loss 3.353122
# iteration 1200 / 1500: loss 2.940838
# iteration 1300 / 1500: loss 2.720741
# iteration 1400 / 1500: loss 3.133496
# Training with learning rate = 5e-06 and reg = 50000.0:
# iteration 0 / 1500: loss 1549.897174
# iteration 100 / 1500: loss 3.288538
# iteration 200 / 1500: loss 3.155016
# iteration 300 / 1500: loss 3.418833
# iteration 400 / 1500: loss 3.370025
# iteration 500 / 1500: loss 4.374286
# iteration 600 / 1500: loss 4.669663
# iteration 700 / 1500: loss 3.734961
# iteration 800 / 1500: loss 2.683150
# iteration 900 / 1500: loss 3.356278
# iteration 1000 / 1500: loss 2.967770
# iteration 1100 / 1500: loss 3.616631
# iteration 1200 / 1500: loss 3.269477
# iteration 1300 / 1500: loss 3.154670
# iteration 1400 / 1500: loss 2.963614
# Training with learning rate = 1e-07 and reg = 10000.0:
# iteration 0 / 1500: loss 315.910072
# iteration 100 / 1500: loss 210.653989
# iteration 200 / 1500: loss 141.624283
# iteration 300 / 1500: loss 95.324336
# iteration 400 / 1500: loss 64.305084
# iteration 500 / 1500: loss 43.738282
# iteration 600 / 1500: loss 29.919756
# iteration 700 / 1500: loss 20.751434
# iteration 800 / 1500: loss 14.523371
# iteration 900 / 1500: loss 10.381451
# iteration 1000 / 1500: loss 7.567515
# iteration 1100 / 1500: loss 5.762760
# iteration 1200 / 1500: loss 4.551883
# iteration 1300 / 1500: loss 3.664803
# iteration 1400 / 1500: loss 3.164459
# Training with learning rate = 1e-07 and reg = 20000.0:
# iteration 0 / 1500: loss 618.625156
# iteration 100 / 1500: loss 277.326201
# iteration 200 / 1500: loss 125.149759
# iteration 300 / 1500: loss 57.130000
# iteration 400 / 1500: loss 26.780394
# iteration 500 / 1500: loss 13.069209
# iteration 600 / 1500: loss 7.081836
# iteration 700 / 1500: loss 4.292904
# iteration 800 / 1500: loss 3.077742
# iteration 900 / 1500: loss 2.519688
# iteration 1000 / 1500: loss 2.326299
# iteration 1100 / 1500: loss 2.166218
# iteration 1200 / 1500: loss 2.103813
# iteration 1300 / 1500: loss 2.045418
# iteration 1400 / 1500: loss 2.111844
# Training with learning rate = 1e-07 and reg = 30000.0:
# iteration 0 / 1500: loss 936.925913
# iteration 100 / 1500: loss 281.397642
# iteration 200 / 1500: loss 85.597558
# iteration 300 / 1500: loss 27.098428
# iteration 400 / 1500: loss 9.568479
# iteration 500 / 1500: loss 4.357027
# iteration 600 / 1500: loss 2.718095
# iteration 700 / 1500: loss 2.291566
# iteration 800 / 1500: loss 2.152958
# iteration 900 / 1500: loss 2.057859
# iteration 1000 / 1500: loss 2.133686
# iteration 1100 / 1500: loss 2.130266
# iteration 1200 / 1500: loss 2.111819
# iteration 1300 / 1500: loss 2.108283
# iteration 1400 / 1500: loss 2.145328
# Training with learning rate = 1e-07 and reg = 40000.0:
# iteration 0 / 1500: loss 1216.523623
# iteration 100 / 1500: loss 244.584913
# iteration 200 / 1500: loss 50.663659
# iteration 300 / 1500: loss 11.834867
# iteration 400 / 1500: loss 4.072977
# iteration 500 / 1500: loss 2.507006
# iteration 600 / 1500: loss 2.210430
# iteration 700 / 1500: loss 2.150931
# iteration 800 / 1500: loss 2.140268
# iteration 900 / 1500: loss 2.185338
# iteration 1000 / 1500: loss 2.162013
# iteration 1100 / 1500: loss 2.150104
# iteration 1200 / 1500: loss 2.115737
# iteration 1300 / 1500: loss 2.102063
# iteration 1400 / 1500: loss 2.141250
# Training with learning rate = 1e-07 and reg = 50000.0:
# iteration 0 / 1500: loss 1524.088616
# iteration 100 / 1500: loss 205.176650
# iteration 200 / 1500: loss 29.229397
# iteration 300 / 1500: loss 5.765452
# iteration 400 / 1500: loss 2.648175
# iteration 500 / 1500: loss 2.198375
# iteration 600 / 1500: loss 2.194410
# iteration 700 / 1500: loss 2.106190
# iteration 800 / 1500: loss 2.156575
# iteration 900 / 1500: loss 2.168011
# iteration 1000 / 1500: loss 2.100854
# iteration 1100 / 1500: loss 2.120589
# iteration 1200 / 1500: loss 2.102135
# iteration 1300 / 1500: loss 2.160391
# iteration 1400 / 1500: loss 2.148529
# Training with learning rate = 5e-07 and reg = 10000.0:
# iteration 0 / 1500: loss 311.917234
# iteration 100 / 1500: loss 42.841747
# iteration 200 / 1500: loss 7.396626
# iteration 300 / 1500: loss 2.720700
# iteration 400 / 1500: loss 2.163773
# iteration 500 / 1500: loss 2.100120
# iteration 600 / 1500: loss 2.044620
# iteration 700 / 1500: loss 2.040318
# iteration 800 / 1500: loss 2.039526
# iteration 900 / 1500: loss 1.992287
# iteration 1000 / 1500: loss 2.014845
# iteration 1100 / 1500: loss 1.982908
# iteration 1200 / 1500: loss 2.035363
# iteration 1300 / 1500: loss 2.035111
# iteration 1400 / 1500: loss 2.045975
# Training with learning rate = 5e-07 and reg = 20000.0:
# iteration 0 / 1500: loss 619.055739
# iteration 100 / 1500: loss 12.877492
# iteration 200 / 1500: loss 2.167243
# iteration 300 / 1500: loss 2.083366
# iteration 400 / 1500: loss 2.092979
# iteration 500 / 1500: loss 2.017336
# iteration 600 / 1500: loss 2.062268
# iteration 700 / 1500: loss 2.085302
# iteration 800 / 1500: loss 2.074424
# iteration 900 / 1500: loss 2.089609
# iteration 1000 / 1500: loss 2.056397
# iteration 1100 / 1500: loss 2.043345
# iteration 1200 / 1500: loss 2.046380
# iteration 1300 / 1500: loss 2.026758
# iteration 1400 / 1500: loss 2.004876
# Training with learning rate = 5e-07 and reg = 30000.0:
# iteration 0 / 1500: loss 922.607108
# iteration 100 / 1500: loss 4.144795
# iteration 200 / 1500: loss 2.099130
# iteration 300 / 1500: loss 2.126674
# iteration 400 / 1500: loss 2.097163
# iteration 500 / 1500: loss 2.050502
# iteration 600 / 1500: loss 2.108245
# iteration 700 / 1500: loss 2.106128
# iteration 800 / 1500: loss 2.106140
# iteration 900 / 1500: loss 2.049946
# iteration 1000 / 1500: loss 2.106635
# iteration 1100 / 1500: loss 2.124552
# iteration 1200 / 1500: loss 2.106629
# iteration 1300 / 1500: loss 2.147325
# iteration 1400 / 1500: loss 2.044804
# Training with learning rate = 5e-07 and reg = 40000.0:
# iteration 0 / 1500: loss 1231.889501
# iteration 100 / 1500: loss 2.483502
# iteration 200 / 1500: loss 2.152971
# iteration 300 / 1500: loss 2.136110
# iteration 400 / 1500: loss 2.120222
# iteration 500 / 1500: loss 2.151261
# iteration 600 / 1500: loss 2.146454
# iteration 700 / 1500: loss 2.105673
# iteration 800 / 1500: loss 2.078519
# iteration 900 / 1500: loss 2.114647
# iteration 1000 / 1500: loss 2.153800
# iteration 1100 / 1500: loss 2.157206
# iteration 1200 / 1500: loss 2.174322
# iteration 1300 / 1500: loss 2.144418
# iteration 1400 / 1500: loss 2.128426
# Training with learning rate = 5e-07 and reg = 50000.0:
# iteration 0 / 1500: loss 1554.566555
# iteration 100 / 1500: loss 2.208502
# iteration 200 / 1500: loss 2.162035
# iteration 300 / 1500: loss 2.167503
# iteration 400 / 1500: loss 2.163350
# iteration 500 / 1500: loss 2.169519
# iteration 600 / 1500: loss 2.160606
# iteration 700 / 1500: loss 2.183144
# iteration 800 / 1500: loss 2.125374
# iteration 900 / 1500: loss 2.136837
# iteration 1000 / 1500: loss 2.115290
# iteration 1100 / 1500: loss 2.184320
# iteration 1200 / 1500: loss 2.165587
# iteration 1300 / 1500: loss 2.113063
# iteration 1400 / 1500: loss 2.105145
# lr 1.000000e-07 reg 1.000000e+04 train accuracy: 0.355959 val accuracy: 0.369000
# lr 1.000000e-07 reg 2.000000e+04 train accuracy: 0.336265 val accuracy: 0.337000
# lr 1.000000e-07 reg 3.000000e+04 train accuracy: 0.323918 val accuracy: 0.332000
# lr 1.000000e-07 reg 4.000000e+04 train accuracy: 0.311510 val accuracy: 0.330000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.310102 val accuracy: 0.324000
# lr 5.000000e-07 reg 1.000000e+04 train accuracy: 0.358020 val accuracy: 0.366000
# lr 5.000000e-07 reg 2.000000e+04 train accuracy: 0.336061 val accuracy: 0.348000
# lr 5.000000e-07 reg 3.000000e+04 train accuracy: 0.325653 val accuracy: 0.327000
# lr 5.000000e-07 reg 4.000000e+04 train accuracy: 0.306122 val accuracy: 0.307000
# lr 5.000000e-07 reg 5.000000e+04 train accuracy: 0.316245 val accuracy: 0.322000
# lr 1.000000e-06 reg 1.000000e+04 train accuracy: 0.349551 val accuracy: 0.354000
# lr 1.000000e-06 reg 2.000000e+04 train accuracy: 0.324245 val accuracy: 0.331000
# lr 1.000000e-06 reg 3.000000e+04 train accuracy: 0.311816 val accuracy: 0.321000
# lr 1.000000e-06 reg 4.000000e+04 train accuracy: 0.311714 val accuracy: 0.324000
# lr 1.000000e-06 reg 5.000000e+04 train accuracy: 0.310347 val accuracy: 0.325000
# lr 5.000000e-06 reg 1.000000e+04 train accuracy: 0.283327 val accuracy: 0.300000
# lr 5.000000e-06 reg 2.000000e+04 train accuracy: 0.204755 val accuracy: 0.217000
# lr 5.000000e-06 reg 3.000000e+04 train accuracy: 0.167796 val accuracy: 0.182000
# lr 5.000000e-06 reg 4.000000e+04 train accuracy: 0.149408 val accuracy: 0.165000
# lr 5.000000e-06 reg 5.000000e+04 train accuracy: 0.149653 val accuracy: 0.166000
# best validation accuracy achieved during cross-validation: 0.369000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.358000

# %% [markdown]
# **Inline Question 2** - *True or False*
#
# Suppose the overall training loss is defined as the sum of the per-datapoint loss over all training examples. It is possible to add a new datapoint to a training set that would leave the SVM loss unchanged, but this is not the case with the Softmax classifier loss.
#
# $\color{blue}{\textit Your Answer:}$ True
#
#
# $\color{blue}{\textit Your Explanation:}$ The loss of a data point in softmax can not be zero, but it can in the case of SVM loss.

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
